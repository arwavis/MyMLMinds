# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Read

# %%
data = pd.read_csv("../Smoke_Detection/smoke_detection_iot.csv")
data
# Out:
#        Unnamed: 0         UTC  Temperature[C]  Humidity[%]  TVOC[ppb]  \
# 0               0  1654733331          20.000        57.36          0
# 1               1  1654733332          20.015        56.67          0
# 2               2  1654733333          20.029        55.96          0
# 3               3  1654733334          20.044        55.28          0
# 4               4  1654733335          20.059        54.69          0
# ...           ...         ...             ...          ...        ...
# 62625       62625  1655130047          18.438        15.79        625
# 62626       62626  1655130048          18.653        15.87        612
# 62627       62627  1655130049          18.867        15.84        627
# 62628       62628  1655130050          19.083        16.04        638
# 62629       62629  1655130051          19.299        16.52        643
#
#        eCO2[ppm]  Raw H2  Raw Ethanol  Pressure[hPa]  PM1.0  PM2.5  NC0.5  \
# ...

# %% [markdown]
# ## Some Plots

# %%
plt.figure(figsize=(12,8))
ax = sns.violinplot(x="Fire Alarm", y="Temperature[C]", data=data)

# %%
plt.figure(figsize=(12,8))
ax = sns.violinplot(x="Fire Alarm", y="Humidity[%]", data=data)

# %%
plt.figure(figsize=(12,8))
ax = sns.violinplot(x="Fire Alarm", y="Pressure[hPa]", data=data)

# %%
plt.figure(figsize=(12,8))
ax = sns.violinplot(x="Fire Alarm", y="Raw H2", data=data)

# %%
plt.figure(figsize=(12,8))
ax = sns.violinplot(x="Fire Alarm", y="Raw Ethanol", data=data)

# %%
plt.figure(figsize=(12,8))
sns.displot(data, x="Pressure[hPa]", kind="kde")

# %%
plt.figure(figsize=(12,8))
sns.displot(data, x="Temperature[C]", kind="kde")

# %%
plt.figure(figsize=(12,8))
sns.displot(data, x="Humidity[%]", kind="kde")

# %%
plt.figure(figsize=(12,8))
corr = data.corr()
sns.heatmap(corr, annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
data.info()#basic idea that we get from the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62630 entries, 0 to 62629
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      62630 non-null  int64
#  1   UTC             62630 non-null  int64
#  2   Temperature[C]  62630 non-null  float64
#  3   Humidity[%]     62630 non-null  float64
#  4   TVOC[ppb]       62630 non-null  int64
#  5   eCO2[ppm]       62630 non-null  int64
#  6   Raw H2          62630 non-null  int64
#  7   Raw Ethanol     62630 non-null  int64
#  8   Pressure[hPa]   62630 non-null  float64
#  9   PM1.0           62630 non-null  float64
#  10  PM2.5           62630 non-null  float64
#  11  NC0.5           62630 non-null  float64
#  12  NC1.0           62630 non-null  float64
#  13  NC2.5           62630 non-null  float64
#  14  CNT             62630 non-null  int64
#  15  Fire Alarm      62630 non-null  int64
# dtypes: float64(8), int64(8)
# memory usage: 7.6 MB

# %%
data.describe()#statistical analysis
# Out:
#          Unnamed: 0           UTC  Temperature[C]   Humidity[%]     TVOC[ppb]  \
# count  62630.000000  6.263000e+04    62630.000000  62630.000000  62630.000000
# mean   31314.500000  1.654792e+09       15.970424     48.539499   1942.057528
# std    18079.868017  1.100025e+05       14.359576      8.865367   7811.589055
# min        0.000000  1.654712e+09      -22.010000     10.740000      0.000000
# 25%    15657.250000  1.654743e+09       10.994250     47.530000    130.000000
# 50%    31314.500000  1.654762e+09       20.130000     50.150000    981.000000
# 75%    46971.750000  1.654778e+09       25.409500     53.240000   1189.000000
# max    62629.000000  1.655130e+09       59.930000     75.200000  60000.000000
#
#           eCO2[ppm]        Raw H2   Raw Ethanol  Pressure[hPa]         PM1.0  \
# count  62630.000000  62630.000000  62630.000000   62630.000000  62630.000000
# mean     670.021044  12942.453936  19754.257912     938.627649    100.594309
# ...

# %% [markdown]
# ## Data Cleaning : Removing Unwanted columns

# %%
# dropping Unnamed column
data = data.drop(data.filter(regex="Unnamed"),axis=1,inplace=False)

# dropping UTC as i find this column is not relevant for evaluation
data=data.drop(['UTC'], axis=1)
data
# Out:
#        Temperature[C]  Humidity[%]  TVOC[ppb]  eCO2[ppm]  Raw H2  Raw Ethanol  \
# 0              20.000        57.36          0        400   12306        18520
# 1              20.015        56.67          0        400   12345        18651
# 2              20.029        55.96          0        400   12374        18764
# 3              20.044        55.28          0        400   12390        18849
# 4              20.059        54.69          0        400   12403        18921
# ...               ...          ...        ...        ...     ...          ...
# 62625          18.438        15.79        625        400   13723        20569
# 62626          18.653        15.87        612        400   13731        20588
# 62627          18.867        15.84        627        400   13725        20582
# 62628          19.083        16.04        638        400   13712        20566
# 62629          19.299        16.52        643        400   13696        20543
#
# ...

# %% [markdown]
# ## Dividing the dataset into dependent and independent columns

# %%
X=data.drop(['Fire Alarm'],axis=1) #independent features from the dataset
y=data['Fire Alarm'] #dependent column from the dataset
X
# Out:
#        Temperature[C]  Humidity[%]  TVOC[ppb]  eCO2[ppm]  Raw H2  Raw Ethanol  \
# 0              20.000        57.36          0        400   12306        18520
# 1              20.015        56.67          0        400   12345        18651
# 2              20.029        55.96          0        400   12374        18764
# 3              20.044        55.28          0        400   12390        18849
# 4              20.059        54.69          0        400   12403        18921
# ...               ...          ...        ...        ...     ...          ...
# 62625          18.438        15.79        625        400   13723        20569
# 62626          18.653        15.87        612        400   13731        20588
# 62627          18.867        15.84        627        400   13725        20582
# 62628          19.083        16.04        638        400   13712        20566
# 62629          19.299        16.52        643        400   13696        20543
#
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 62625    0
# 62626    0
# 62627    0
# 62628    0
# 62629    0
# Name: Fire Alarm, Length: 62630, dtype: int64

# %% [markdown]
# ## Splitting the dataset into training and testing set

# %% [markdown]
# ### 20% of the dataset will be used for testing(evaluation) and 80% of the data will be used for training purposes

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %% [markdown]
# ## Logistic Regression Algorithm

# %%
from sklearn.linear_model import LogisticRegression
logmodel=LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# C:\Users\aravindv\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=logmodel.predict(X_test)

# %%
print(y_pred)
# Out:
# [1 1 1 ... 1 0 1]

# %%
#calculating accuracy of the Classification model
from sklearn.metrics import confusion_matrix, accuracy_score
log_cm=confusion_matrix(y_test,y_pred)
log_ac=accuracy_score(y_test,y_pred)

# %%
print(log_cm)
# Out:
# [[3554   28]
#  [ 184 8760]]

# %%
print(log_ac)
# Out:
# 0.9830752035765608

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
tree_classifier=DecisionTreeClassifier()

# %%
tree_classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions=tree_classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
dc_cm=confusion_matrix(y_test,predictions)
dc_ac=accuracy_score(y_test,predictions)

# %%
print(dc_cm)
# Out:
# [[3582    0]
#  [   2 8942]]

# %%
print(dc_ac)
# Out:
# 0.9998403321092129

# %% [markdown]
# ## KNN Algorithm

# %%
#importing KNN Classfier
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=11)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
predictions=knn.predict(X_test)

# %%
#accuracy
from sklearn.metrics import confusion_matrix,accuracy_score
knn_cm=confusion_matrix(y_test,predictions)
knn_ac=accuracy_score(y_test,predictions)

# %%
print(knn_cm)
# Out:
# [[3579    3]
#  [   2 8942]]

# %%
print(knn_ac)
# Out:
# 0.9996008302730321

# %% [markdown]
# ## Random Forest Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()

# %%
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

rf_cm=confusion_matrix(y_test,y_pred)
rf_ac=accuracy_score(y_test,y_pred)

# %%
print(rf_cm)
# Out:
# [[3582    0]
#  [   0 8944]]

# %%
print(rf_ac)
# Out:
# 1.0

# %% [markdown]
# ## Support Vector Machine Algorithm

# %%
from sklearn.svm import SVC
svc_model=SVC()

# %%
svc_model.fit(X_train,y_train)
# Out:
# SVC()

# %%
predictions=svc_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

svm_cm=confusion_matrix(y_test,predictions)
svm_ac=accuracy_score(y_test,predictions)

# %%
print(svm_cm)
# Out:
# [[3536   46]
#  [ 216 8728]]

# %%
print(svm_ac)
# Out:
# 0.9790835063068817

# %%
print(f"logistic regression Accuracy {log_ac*100}")
print(f"Decision Tree Accuracy {dc_ac*100}")
print(f"KNN Accuracy {knn_ac*100}")
print(f"Random Forest Accuracy {rf_ac*100}")
print(f"Support Vector Machine Accuracy {svm_ac*100}")
# Out:
# logistic regression Accuracy 98.30752035765607
# Decision Tree Accuracy 99.98403321092128
# KNN Accuracy 99.96008302730321
# Random Forest Accuracy 100.0
# Support Vector Machine Accuracy 97.90835063068816
